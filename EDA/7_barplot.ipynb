# %% [markdown]
# ## Veri Görselleştirme

# %% [markdown]
# ### barplot

# %% [markdown]
# *Kategorik değişkenlerin görselleştirilmesinde kullanılır.*<br>

# %% [markdown]
# *"diamonds" veri setindeki kategorik değişken sıralamalarını yeniden yapalım ve veri görselleştirmeye başlayalım.*<br>

# %%
import seaborn as sns
diamonds= sns.load_dataset("diamonds")
df = diamonds.copy()
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
from pandas.api.types import CategoricalDtype
cut_categories = ["Fair", "Good", "Very Good", "Premium", "Ideal"]
color_categories = ["J", "I", "H", "G", "F", "E", "D"]
clarity_categories = ["I1", "SI2", "SI1", "VS2", "VS1", "VVS2", "VVS1", "IF"]

df.cut = df.cut.astype(CategoricalDtype(categories = cut_categories, ordered = True))
df.color = df.color.astype(CategoricalDtype(categories = color_categories, ordered = True))
df.clarity = df.clarity.astype(CategoricalDtype(categories = clarity_categories, ordered = True))

# %%
df.cut.head(1)
# Out:
# 0    Ideal
# Name: cut, dtype: category
# Categories (5, object): ['Fair' < 'Good' < 'Very Good' < 'Premium' < 'Ideal']

# %%
df.color.head(1)
# Out:
# 0    E
# Name: color, dtype: category
# Categories (7, object): ['J' < 'I' < 'H' < 'G' < 'F' < 'E' < 'D']

# %%
df.clarity.head(1)
# Out:
# 0    SI2
# Name: clarity, dtype: category
# Categories (8, object): ['I1' < 'SI2' < 'SI1' < 'VS2' < 'VS1' < 'VVS2' < 'VVS1' < 'IF']

# %%
#barplot

# %%
(df["cut"].
 value_counts()
 .plot.barh()
 .set_title("Cut Değişkenine Ait Sınıf Frekansları"));

# %%
#seaborn ile görselleştirme
sns.barplot( x = "cut", y = df.cut.index, data = df);
