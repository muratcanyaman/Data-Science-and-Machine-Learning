# %% [markdown]
# # Multinomial Distribution (Çok Terimli Dağılım) 🚀

# %% [markdown]
# ℹ️ *Çok Terimli Dağılım, İkili(Binomial) Dağılım'ın genelleştirilmiş halidir.*<br>
# ℹ️ *İkili senaryoların aksine, senaryoların sadece ikisinden biri olması gereken çok terimli senaryoların sonuçlarını açıklar.Bir nufüsa ait kan grubu sonuçları, zar atma sonuçları vs.*<br>
# ℹ️ *3 parametre alır:*<br>
# **n**: Deneyin çalıştırılma sayısını ifade eder.<br>
# **pvals**: Sonuçların olasılıklarının bir listesini temsil eder.( Örnek : Atılan zarların sonuçları -> [1/6, 1/6, 1/6, 1/6, 1/6, 1/6])<br>
# **size**: Geriye döndürülen dizinin boyutu.<br>

# %% [markdown]
# *Zar atışı için bir örnek çıkaralım:*<br>

# %%
from numpy import random

x = random.multinomial(n = 6, pvals = [1/6,1/6,1/6,1/6,1/6,1/6])
print(x)
# Out:
# [0 0 2 2 1 1]

# %% [markdown]
# ⭐ *Çok terimli örneklemler sadece tek bir değer üretmezler! Her bir **pval** değeri için bir değer üretirler.<br>

# %% [markdown]
# ⭐*Bunlar ikili dağılımın genelleştirilmesi olduğu için, görsel temsilleri ve ve normal dağılıma olan benzerlikleri,çoklu binom dağılımındakilere benzerlik gösterir.*<br>
