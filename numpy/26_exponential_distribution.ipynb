# %% [markdown]
# # Exponential Distribution (Üstel Dağılım) 🚀

# %% [markdown]
# ℹ️ *Üstel Dağılım bir sonraki olayın gerçekleşmesine kadar geçen süreyi ifade eder.*<br>
# ℹ️ * 2 parametre alır:<br>
# **scale**: Oranın tersi.Varsayılan olarak 1'dir.*<br>
# **size**: Geriye dönen dizinin şekli.*<br>

# %% [markdown]
# *Üstel dağılım için scale değeri 2.0 ve 2x3 boyutunda bir örnek çizelim:*<br>

# %%
from  numpy import random

x = random.exponential( scale = 2, size = (2,3))
print(x)
# Out:
# [[7.76185454 3.24904514 5.1700658 ]
#  [6.20467767 1.21840184 0.66464017]]

# %% [markdown]
# # Üstel Dağılım Grafiği 🧠

# %% [markdown]
# from numpy import random
# import matplotlib.pyplot as plt
# import seaborn as sns
#
# sns.displot(random.exponential(size = 1000), kind = "kde")
# plt.show()

# %% [markdown]
# ## Poisson Dağılımı ile Exponential Dağılım Arasındaki İlişki 🧠

# %% [markdown]
# 📌 *Poisson Dağılımı bir olayın gerçekleşme sayısı ile ilgilenirken Exponential Dağılımı bu olaylar arasında geçen zaman ile ilgilenir.*
