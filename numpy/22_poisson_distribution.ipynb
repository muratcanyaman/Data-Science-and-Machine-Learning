# %% [markdown]
# # Poission Dağılımı 🚀

# %% [markdown]
# ℹ️ *Poission Dağılımı ayrık bir dağılımdır.*<br>
# ℹ️ *Belirli bir zaman dilimi içerisinde bir olayın kaç defa gerçekleşebileceğini tahmin eder.Örneğin bir bir kişi günde 2 öğün yemek yiyorsa bu kişinin günde 3 öğün yeme olasılığı nedir?*<br>
# ℹ️ *İki parametre alır:*<br>
#     ***lam**:oran veya bilinen olay sayısı*<br>
#     ***size**: döndürülen dizinin boyutu*

# %% [markdown]
# *Oluşum 2 için 1x10'luk rastgele dağılım üretelim:*

# %%
from numpy import random

x = random.poisson(lam = 2, size = 10)
print(x)
# Out:
# [1 2 6 1 1 2 3 2 3 1]

# %% [markdown]
# ## Poission Dağılımının Görselleştirilmesi 🧠

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

sns.displot(random.poisson(lam = 2, size = 1000))
plt.show()

# %% [markdown]
# ## Normal Dağılım ile Poisson Dağılımı Arasındaki Fark 🧠

# %% [markdown]
# ℹ️ *Binom Dağılımında olduğu gibi burda da Normal Dağılım sürekli iken Poisson Dağılımı ayrıktır.<br>*
# ℹ️ *Ancak yeterince büyük bir Poisson Dağılımı için Binom Dağılımında olduğu gibi belirli bir standart sapma ve ortalamaya sahip normal dağılıma benzeyeceğini görebiliriz.*

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

data = {

    "normal" : random.normal(loc = 50, scale = 7, size = 1000),
    "poisson" : random.poisson(lam = 50, size = 1000)
}

sns.displot(data, kind = "kde")
plt.show()

# %% [markdown]
# ## Binom Dağılımı ile Poisson Dağılımı Arasındaki Fark 🧠

# %% [markdown]
# ℹ️ *Binom Dağılımı en fazla 2 olası sonuca sahiptir.Fakat Poisson Dağılımında sınırsız sayıda olası değer elde edebiliriz*<br>
# ℹ️ *Fakat çok büyük **n** ve sıfıra yakın **p** değerlerinde,**nxp** değerinin **lam** değerine neredeyse eşit olduğu şekilde binom dağılımı kimlik olarak possion dağılımına benzer.*

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sls

data = {

    "binom" : random.binomial( n = 1000, p = 0.01, size = 1000),
    "poisson" : random.poisson(lam = 10, size = 1000)
}

sls.displot(data, kind = "kde")
plt.show()
