# %% [markdown]
# # Uniform Distribution(Tekdüze Dağılım) 🚀

# %% [markdown]
# ℹ️ *Her olayın gerçekleşme ihtimalinin eşit olduğu olasılıkları ifade ederken kullanılan bir dağılımdır.*<br>
# ℹ️ *Örneğin rastgele sayıların üretimi.*<br>
# ℹ️ *3 parametre alır :*<br>
# ***low**: Alt sınır.Varsayılan olarak 0.0*<br>
# ***high**: Üst sınır.Varsayılan olarak 1.0*<br>
# ***size**: Geriye döndürülen dizinin boyutu*

# %%
# 2x3 boyutunda Uniform dağılım örneği oluşturalım
from numpy import random
x = random.uniform(size = (2,3))
print(x)
# Out:
# [[0.93693146 0.17638342 0.8440372 ]
#  [0.06920789 0.13395657 0.87075971]]

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

sns.displot(random.uniform(size = 1000), kind = 'kde')
plt.show()
