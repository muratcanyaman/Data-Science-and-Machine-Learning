# %% [markdown]
# # Pareto Distribution (Pareto Dağılımı) 🚀

# %% [markdown]
# ℹ️ *İsmini Pareto Yasası'ndan alan dağılım(%20'lik faktörler %80'lik dağılımı oluşturur).*<br>
# ℹ️ *İki parametre alır:*<br>
# **a**: Şekil parametresi.*<br>
# **size**: Dönen dizinin boyutu.*

# %% [markdown]
# *2x3 boyutunda şekli 2 olan Pareto Dağılım örneklemi çizelim:*<br>

# %%
from numpy import random

x = random.pareto(a = 2, size = (2, 3))
print(x)
# Out:
# [[2.09429481 0.10296948 1.42693323]
#  [0.00276771 0.5683852  2.15050825]]

# %% [markdown]
# ## Pareto Dağılım Grafiği

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

sns.displot(random.pareto(a=2, size=1000))

plt.show()
