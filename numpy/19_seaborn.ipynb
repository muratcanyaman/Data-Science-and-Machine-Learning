# %% [markdown]
# # Seaborn 🚀

# %% [markdown]
# ## Seaborn Kullanarak Veri Görselleştirme 🧠

# %% [markdown]
# ℹ️ *Seaborn, Matplotlib'i kullanarak grafik çizmeye yarayan bir kütüphanedir.Rastgele dağılımların görselleştirilmesinde kullanılır.*<br>

# %% [markdown]
# ## Seaborn Kurulumu 🧠

# %% [markdown]
# *Halihazırda Python ve PIP var ise aşağıdaki komutla kütüphaneyi sisteminize kurabilirsiniz:*

# %% [markdown]
# <pre>C:\Users\Your Name>pip install seaborn</pre>

# %% [markdown]
# *Jupyter kullanıyorsanız:*

# %% [markdown]
# <pre>C:\Users\Your Name>!pip install seaborn</pre>

# %% [markdown]
# ## Displot 🧠

# %% [markdown]
# ℹ️ *Displot,Distribution Plot yani Dağılım Grafiği'nin kısaltılmış halidir.Input olarak bir dizi alır ve bu dizi noktalarının dağılımına karşılık gelen bir eğri çizer.*

# %% [markdown]
# ### import matplotlib

# %% [markdown]
# *matplotlib içerisindeki pyplot objesini import etme:*

# %%
import matplotlib.pyplot as plp

# %% [markdown]
# ### import seaborn

# %%
import seaborn as sns

# %% [markdown]
# ⚠️ *seaborn modülü ile noktalar kümesinin dağılım grafiğini çizeriz,matplotlib kullanarak bu grafikleri kullanıcıya gösteririz.*

# %% [markdown]
# ## Dağılım Grafiği Çizmek 🧠

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.displot([0,1,2,3,4,5], kind = "kde")
plt.show()
